# %%
import pandas as pd

# %%
import pandas as pd

lists = pd.read_csv('listings_with_rates.csv')
sold = pd.read_csv('sold_with_rates.csv')
before_row_count = {'lists' : len(lists),
                   'sold' : len(sold)}


#CONVERTING TO DATETTIME
dt_cols = ['CloseDate', 'PurchaseContractDate', 'ListingContractDate', 'ContractStatusChangeDate']
lists[dt_cols] = lists[dt_cols].apply(pd.to_datetime)
sold[dt_cols] = sold[dt_cols].apply(pd.to_datetime)



#INITIAL CLEANING
def flagging(df):
    df['invalid_closeprice_flag'] = df['ClosePrice'] <= 0
    df['invalid_livingarea_flag'] = df['LivingArea'] <= 0
    df['invalid_dom_flag'] = df['DaysOnMarket'] < 0
    df['invalid_bed_flag'] = df['BedroomsTotal'] < 0
    df['invalid_bath_flag'] = df['BathroomsTotalInteger'] < 0
flagging(lists)
flagging(sold)


#CHECKING VALID DATETIME ORDER
def dt_order(df):
    df['listing_after_close_flag'] = (
        (df['ListingContractDate'] > df['CloseDate']) &
        df['CloseDate'].notna()
    )

    df['purchase_after_close_flag'] = (
        (df['PurchaseContractDate'] > df['CloseDate']) &
        df['CloseDate'].notna()
    )

    df['negative_timeline_flag'] = (
        ((df['PurchaseContractDate'] < df['ListingContractDate']) & df['PurchaseContractDate'].notna()) |
        ((df['CloseDate'] < df['PurchaseContractDate']) & df['CloseDate'].notna())
    )   
dt_order(lists)
dt_order(sold)

#CHECKING VALID GEO ORDER
def geo_check(df):
    df['invalid_geo_flag'] = (
        df['Latitude'].isna() | df['Longitude'].isna() |
        (df['Latitude'] == 0) | (df['Longitude'] == 0) |
        (df['Longitude'] > 0) |
        (df['Latitude'] < 32) | (df['Latitude'] > 42) |
        (df['Longitude'] < -125) | (df['Longitude'] > -114)
    )
    return df
geo_check(lists)
geo_check(sold)


###############SUMMARY###############
flag_cols = [
    'invalid_closeprice_flag', 'invalid_livingarea_flag',
    'invalid_dom_flag', 'invalid_bed_flag', 'invalid_bath_flag',
    'listing_after_close_flag', 'purchase_after_close_flag',
    'negative_timeline_flag', 'invalid_geo_flag'
]

def summarize_flags(df, name):
    print(f"\n--- {name.upper()} DATA QUALITY SUMMARY ---")
    for col in flag_cols:
        print(f"{col}: {df[col].sum()} flagged rows")
        
summarize_flags(lists, "lists")
summarize_flags(sold, "sold")

#GEO SUMMARY
def geo_summary(df, name):
    total_invalid = df['invalid_geo_flag'].sum()
    print(f"\n--- {name.upper()} GEO SUMMARY ---")
    print("Invalid coordinate records:", total_invalid)

geo_summary(lists, "lists")
geo_summary(sold, "sold")

#DROPPING INVALIDS + ROW SUMMARY
lists = lists[~lists[flag_cols].any(axis=1)].drop(columns = flag_cols)
sold = sold[~sold[flag_cols].any(axis=1)].drop(columns = flag_cols)
after_row_count = {
    'lists': len(lists),
    'sold': len(sold)
}
print("\n--- ROW COUNT SUMMARY ---")
print("Lists: before =", before_row_count['lists'],
      "| after =", after_row_count['lists'],
      "| removed =", before_row_count['lists'] - after_row_count['lists'])

print("Sold: before =", before_row_count['sold'],
      "| after =", after_row_count['sold'],
      "| removed =", before_row_count['sold'] - after_row_count['sold'])
# Out:
# /var/folders/yq/2brk2z0n079bpg5ghhk54lvr0000gn/T/ipykernel_48188/3835526500.py:3: DtypeWarning: Columns (0: ListAgentEmail, 1: CloseDate, 2: BuyerOfficeName, 3: BuyerAgentMlsId, 4: BuyerAgentFirstName, 5: BuyerAgentLastName, 6: ElementarySchool, 7: BuyerOfficeAOR, 8: MiddleOrJuniorSchool, 9: YearMonth, 10: BuyerAgencyCompensationType) have mixed types. Specify dtype option on import or set low_memory=False.
#   lists = pd.read_csv('listings_with_rates.csv')
# /var/folders/yq/2brk2z0n079bpg5ghhk54lvr0000gn/T/ipykernel_48188/3835526500.py:4: DtypeWarning: Columns (0: BuyerAgentAOR, 1: ListAgentAOR, 2: ListAgentEmail, 3: ElementarySchool, 4: MiddleOrJuniorSchool, 5: latfilled, 6: lonfilled, 7: OriginatingSystemName, 8: OriginatingSystemSubName, 9: BuyerAgencyCompensationType) have mixed types. Specify dtype option on import or set low_memory=False.
#   sold = pd.read_csv('sold_with_rates.csv')
# --- LISTS DATA QUALITY SUMMARY ---
# invalid_closeprice_flag: 11 flagged rows
# invalid_livingarea_flag: 803 flagged rows
# invalid_dom_flag: 37 flagged rows
# invalid_bed_flag: 0 flagged rows
# invalid_bath_flag: 0 flagged rows
# listing_after_close_flag: 107 flagged rows
# purchase_after_close_flag: 311 flagged rows
# negative_timeline_flag: 690 flagged rows
# invalid_geo_flag: 111818 flagged rows
#
# --- SOLD DATA QUALITY SUMMARY ---
# invalid_closeprice_flag: 34 flagged rows
# invalid_livingarea_flag: 467 flagged rows
# invalid_dom_flag: 59 flagged rows
# invalid_bed_flag: 0 flagged rows
# invalid_bath_flag: 0 flagged rows
# listing_after_close_flag: 104 flagged rows
# purchase_after_close_flag: 347 flagged rows
# negative_timeline_flag: 704 flagged rows
# invalid_geo_flag: 18956 flagged rows
#
# --- LISTS GEO SUMMARY ---
# Invalid coordinate records: 111818
#
# --- SOLD GEO SUMMARY ---
# Invalid coordinate records: 18956
#
# --- ROW COUNT SUMMARY ---
# Lists: before = 814907 | after = 701769 | removed = 113138
# Sold: before = 568150 | after = 548038 | removed = 20112

# %%
lists.to_csv('listings_with_rates.csv', index=False)
sold.to_csv('sold_with_rates.csv', index=False)
print("\nDatasets saved.")
# Out:
# Datasets saved.

# %%
lists
# Out:
#         OriginalListPrice  ListingKey              ListAgentEmail CloseDate  \
# 2               1400000.0  1076193814  alizabethjames@hotmail.com       NaT
# 8                199990.0  1076192982     micah.homepro@gmail.com       NaT
# 11               835000.0  1076190486         Rita@ritaharper.com       NaT
# 12              1150000.0  1076190201       willsellsre@gmail.com       NaT
# 15               849000.0  1076189641          kingadorosz@kw.com       NaT
# ...                   ...         ...                         ...       ...
# 814902            25000.0  1061308992         robin@cbborrego.com       NaT
# 814903           625000.0  1060129455         joel@ripfritzer.com       NaT
# 814904           409000.0  1058408504  marierealtor4you@gmail.com       NaT
# 814905          3900000.0  1038675566         brettbman@gmail.com       NaT
# 814906          1825000.0  1038248402      taylor@willisallen.com       NaT
#
#        ListAgentFirstName  ListAgentLastName   Latitude   Longitude  \
# 2               Alizabeth              James  33.858559 -116.542169
# 8                   Micah  Swarthout Kerrico  32.777540 -115.553772
# 11                   Rita             Harper  33.166112 -117.266548
# 12                 Wilbur             Wester  33.212280 -117.218628
# 15                  Kinga             Dorosz  34.099671 -118.254039
# ...                   ...                ...        ...         ...
# 814902              Robin           Reynolds  33.273002 -115.953189
# 814903               Joel              Cloud  32.773679 -116.933649
# 814904              Marie          Arredondo  33.207200 -116.299900
# 814905              Brett            Baumann  37.497693 -120.046471
# 814906             Taylor              Smith  32.617947 -117.134345
#
#                            UnparsedAddress PropertyType  ...  AssociationFee  \
# 2                        505 E Molino Road  Residential  ...             NaN
# 8                        1826 S 4th Street  Residential  ...           324.0
# 11                        4645 Cordoba Way  Residential  ...           663.0
# 12                          1517 Via Pedro  Residential  ...             0.0
# 15                   2376 Lake View Avenue  Residential  ...             NaN
# ...                                    ...          ...  ...             ...
# 814902                1102 Stanford Avenue         Land  ...             0.0
# 814903                     1725 Grove Road         Land  ...             0.0
# 814904               3135 Club Circle East  Residential  ...             0.0
# 814905  665 Acs. - Mt Bullion Cut-Off Road         Land  ...             0.0
# 814906                   5 Bridgetown Bend  Residential  ...           331.0
#
#         LotSizeSquareFeet  YearMonth ClosePrice PriceRatio PricePerSqFt  \
# 2                 10890.0        NaN        NaN        NaN          NaN
# 8                   680.0        NaN        NaN        NaN          NaN
# 11                 4500.0        NaN        NaN        NaN          NaN
# 12                21780.0        NaN        NaN        NaN          NaN
# 15                 4800.0        NaN        NaN        NaN          NaN
# ...                   ...        ...        ...        ...          ...
# 814902            13503.6        NaN        NaN        NaN          NaN
# 814903            43560.0        NaN        NaN        NaN          NaN
# 814904            34848.0        NaN        NaN        NaN          NaN
# 814905         28980903.6        NaN        NaN        NaN          NaN
# 814906             3959.0        NaN        NaN        NaN          NaN
#
#        BuyerAgencyCompensationType BuyerAgencyCompensation year_month  \
# 2                              NaN                     NaN    2024-05
# 8                              NaN                     NaN    2024-05
# 11                             NaN                     NaN    2024-05
# 12                             NaN                     NaN    2024-05
# 15                             NaN                     NaN    2024-05
# ...                            ...                     ...        ...
# 814902                         NaN                     NaN    2024-08
# 814903                         NaN                     NaN    2024-08
# 814904                         NaN                     NaN    2024-08
# 814905                         NaN                     NaN    2024-08
# 814906                         NaN                     NaN    2024-08
#
#        rate_30yr_fixed
# 2                 7.06
# 8                 7.06
# 11                7.06
# 12                7.06
# 15                7.06
# ...                ...
# 814902            6.50
# 814903            6.50
# 814904            6.50
# 814905            6.50
# 814906            6.50
#
# [701769 rows x 66 columns]

# %%
list
sold['CloseToOriginalListRatio'] = sold['ClosePrice']/sold['OriginalListPrice']

# %%
sold['CloseToOriginalListRatio']
# Out:
# 0         0.964602
# 1         0.557103
# 2         0.131303
# 3         1.000000
# 4         1.151920
#             ...
# 568144    1.402667
# 568145    0.693374
# 568146    1.000000
# 568147    0.363636
# 568149    0.656250
# Name: CloseToOriginalListRatio, Length: 548038, dtype: float64

# %%
lists['CloseToOriginalListRatio'] = lists['ClosePrice']/lists['OriginalListPrice']

# %%
lists['CloseToOriginalListRatio']
# Out:
# 2        NaN
# 8        NaN
# 11       NaN
# 12       NaN
# 15       NaN
#           ..
# 814902   NaN
# 814903   NaN
# 814904   NaN
# 814905   NaN
# 814906   NaN
# Name: CloseToOriginalListRatio, Length: 701769, dtype: float64

# %%
sold['ListingToContractDays'] = sold['PurchaseContractDate'] - sold['ListingContractDate']
lists['ContractToCloseDays'] = lists['PurchaseContractDate'] - lists['ListingContractDate']
# Out:
#         OriginalListPrice  ListingKey              ListAgentEmail CloseDate  \
# 2               1400000.0  1076193814  alizabethjames@hotmail.com       NaT
# 8                199990.0  1076192982     micah.homepro@gmail.com       NaT
# 11               835000.0  1076190486         Rita@ritaharper.com       NaT
# 12              1150000.0  1076190201       willsellsre@gmail.com       NaT
# 15               849000.0  1076189641          kingadorosz@kw.com       NaT
# ...                   ...         ...                         ...       ...
# 814902            25000.0  1061308992         robin@cbborrego.com       NaT
# 814903           625000.0  1060129455         joel@ripfritzer.com       NaT
# 814904           409000.0  1058408504  marierealtor4you@gmail.com       NaT
# 814905          3900000.0  1038675566         brettbman@gmail.com       NaT
# 814906          1825000.0  1038248402      taylor@willisallen.com       NaT
#
#        ListAgentFirstName  ListAgentLastName   Latitude   Longitude  \
# 2               Alizabeth              James  33.858559 -116.542169
# 8                   Micah  Swarthout Kerrico  32.777540 -115.553772
# 11                   Rita             Harper  33.166112 -117.266548
# 12                 Wilbur             Wester  33.212280 -117.218628
# 15                  Kinga             Dorosz  34.099671 -118.254039
# ...                   ...                ...        ...         ...
# 814902              Robin           Reynolds  33.273002 -115.953189
# 814903               Joel              Cloud  32.773679 -116.933649
# 814904              Marie          Arredondo  33.207200 -116.299900
# 814905              Brett            Baumann  37.497693 -120.046471
# 814906             Taylor              Smith  32.617947 -117.134345
#
#                            UnparsedAddress PropertyType  ...  YearMonth  \
# 2                        505 E Molino Road  Residential  ...        NaN
# 8                        1826 S 4th Street  Residential  ...        NaN
# 11                        4645 Cordoba Way  Residential  ...        NaN
# 12                          1517 Via Pedro  Residential  ...        NaN
# 15                   2376 Lake View Avenue  Residential  ...        NaN
# ...                                    ...          ...  ...        ...
# 814902                1102 Stanford Avenue         Land  ...        NaN
# 814903                     1725 Grove Road         Land  ...        NaN
# 814904               3135 Club Circle East  Residential  ...        NaN
# 814905  665 Acs. - Mt Bullion Cut-Off Road         Land  ...        NaN
# 814906                   5 Bridgetown Bend  Residential  ...        NaN
#
#         ClosePrice  PriceRatio PricePerSqFt BuyerAgencyCompensationType  \
# 2              NaN         NaN          NaN                         NaN
# 8              NaN         NaN          NaN                         NaN
# 11             NaN         NaN          NaN                         NaN
# 12             NaN         NaN          NaN                         NaN
# 15             NaN         NaN          NaN                         NaN
# ...            ...         ...          ...                         ...
# 814902         NaN         NaN          NaN                         NaN
# 814903         NaN         NaN          NaN                         NaN
# 814904         NaN         NaN          NaN                         NaN
# 814905         NaN         NaN          NaN                         NaN
# 814906         NaN         NaN          NaN                         NaN
#
#        BuyerAgencyCompensation year_month rate_30yr_fixed  \
# 2                          NaN    2024-05            7.06
# 8                          NaN    2024-05            7.06
# 11                         NaN    2024-05            7.06
# 12                         NaN    2024-05            7.06
# 15                         NaN    2024-05            7.06
# ...                        ...        ...             ...
# 814902                     NaN    2024-08            6.50
# 814903                     NaN    2024-08            6.50
# 814904                     NaN    2024-08            6.50
# 814905                     NaN    2024-08            6.50
# 814906                     NaN    2024-08            6.50
#
#        CloseToOriginalListRatio ContractToCloseDays
# 2                           NaN                 NaT
# 8                           NaN                 NaT
# 11                          NaN                 NaT
# 12                          NaN                 NaT
# 15                          NaN                 NaT
# ...                         ...                 ...
# 814902                      NaN                 NaT
# 814903                      NaN                 NaT
# 814904                      NaN                 NaT
# 814905                      NaN                 NaT
# 814906                      NaN                 NaT
#
# [701769 rows x 68 columns]

# %%
#ADDING CloseToOriginalList
sold['CloseToOriginalListRatio'] = sold['ClosePrice']/sold['OriginalListPrice']
lists['CloseToOriginalListRatio'] = lists['ClosePrice']/lists['OriginalListPrice']

#ADDING ListingToContractDays
sold['ListingToContractDays'] = sold['PurchaseContractDate'] - sold['ListingContractDate']
lists['ListingToContractDays'] = lists['PurchaseContractDate'] - lists['ListingContractDate']

#ADDING ContractToCloseDays
sold['ContractToCloseDays'] = sold['CloseDate'] - sold['PurchaseContractDate']
lists['ContractToCloseDays'] = lists['CloseDate'] - lists['PurchaseContractDate']



def segment_summary(df, group_cols):
    return (
        df.groupby(group_cols)
        .agg(
            count=('ClosePrice', 'size'),
            median_price=('ClosePrice', 'median'),
            avg_price=('ClosePrice', 'mean'),
            median_ppsqft=('PricePerSqFt', 'median'),
            avg_ppsqft=('PricePerSqFt', 'mean'),
            avg_dom=('DaysOnMarket', 'mean'),
            avg_price_ratio=('PriceRatio', 'mean'),
            avg_list_to_contract=('ListingToContractDays', 'mean'),
            avg_contract_to_close=('ContractToCloseDays', 'mean')
        )
        .sort_values('count', ascending=False)
    )

# %%
property_summary = segment_summary(sold, ['PropertyType', 'PropertySubType'])

# %%
property_summary
# Out:
#                                           count  median_price     avg_price  \
# PropertyType      PropertySubType
# Residential       SingleFamilyResidence  274147      880000.0  1.274643e+06
# ResidentialLease  SingleFamilyResidence   59789        4450.0  1.149005e+04
# Residential       Condominium             59787      625000.0  8.883552e+05
# ResidentialLease  Condominium             35332        3495.0  4.758202e+03
# Residential       Townhouse               21136      800000.0  1.003224e+06
# ...                                         ...           ...           ...
# CommercialSale    SingleFamilyResidence       1      319000.0  3.190000e+05
# Land              MixedUse                    1       70000.0  7.000000e+04
# ResidentialIncome Loft                        1     4300000.0  4.300000e+06
#                   Cabin                       1      314000.0  3.140000e+05
# CommercialLease   Agriculture                 1        2800.0  2.800000e+03
#
#                                          median_ppsqft  avg_ppsqft  \
# PropertyType      PropertySubType
# Residential       SingleFamilyResidence     526.428462  627.897560
# ResidentialLease  SingleFamilyResidence       2.650957    5.860579
# Residential       Condominium               561.979130  716.759426
# ResidentialLease  Condominium                 3.000000    4.143710
# Residential       Townhouse                 557.766742  645.456630
# ...                                                ...         ...
# CommercialSale    SingleFamilyResidence            NaN         NaN
# Land              MixedUse                         NaN         NaN
# ResidentialIncome Loft                             NaN         NaN
#                   Cabin                            NaN         NaN
# CommercialLease   Agriculture                      NaN         NaN
#
#                                             avg_dom  avg_price_ratio  \
# PropertyType      PropertySubType
# Residential       SingleFamilyResidence   36.568834        69.123962
# ResidentialLease  SingleFamilyResidence   38.510228         2.082384
# Residential       Condominium             41.875408        29.341713
# ResidentialLease  Condominium             41.028671         1.243953
# Residential       Townhouse               32.449092        47.478240
# ...                                             ...              ...
# CommercialSale    SingleFamilyResidence    0.000000         0.864499
# Land              MixedUse               743.000000         0.667302
# ResidentialIncome Loft                     0.000000         0.860861
#                   Cabin                  131.000000         0.957317
# CommercialLease   Agriculture             11.000000         1.000000
#
#                                            avg_list_to_contract  \
# PropertyType      PropertySubType
# Residential       SingleFamilyResidence 44 days 18:36:19.628480
# ResidentialLease  SingleFamilyResidence 44 days 15:15:57.149561
# Residential       Condominium           49 days 06:17:52.750707
# ResidentialLease  Condominium           44 days 02:54:28.694284
# Residential       Townhouse             38 days 21:39:43.698584
# ...                                                         ...
# CommercialSale    SingleFamilyResidence                     NaT
# Land              MixedUse                    746 days 00:00:00
# ResidentialIncome Loft                          0 days 00:00:00
#                   Cabin                       132 days 00:00:00
# CommercialLease   Agriculture                  19 days 00:00:00
#
#                                           avg_contract_to_close
# PropertyType      PropertySubType
# Residential       SingleFamilyResidence 31 days 19:32:42.033502
# ResidentialLease  SingleFamilyResidence  4 days 22:42:52.932385
# Residential       Condominium           30 days 15:47:55.444410
# ResidentialLease  Condominium            4 days 14:52:15.605663
# Residential       Townhouse             31 days 05:39:13.708524
# ...                                                         ...
# CommercialSale    SingleFamilyResidence                     NaT
# Land              MixedUse                    960 days 00:00:00
# ResidentialIncome Loft                        119 days 00:00:00
#                   Cabin                        23 days 00:00:00
# CommercialLease   Agriculture                   1 days 00:00:00
#
# [86 rows x 9 columns]

# %%
prop_summ = segment_summary(sold, ['PropertyType', 'PropertySubType'])
loc_summ = segment_summary(sold, ['CountyOrParish', 'MLSAreaMajor'])
list_off_summ = segment_summary(sold, ['ListOfficeName'])
buy_off_summ = segment_summary(sold, ['BuyerOfficeName'])


prop_summ.to_csv('property_type_comparison.csv')
loc_summ.to_csv('location_comparison.csv')

#UPDATE CURR CSVs
lists.to_csv('listings_with_rates.csv', index=False)
sold.to_csv('sold_with_rates.csv', index=False)
print("\nDatasets saved.")
# Out:
# Datasets saved.
